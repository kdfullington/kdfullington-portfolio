# %%
import pandas as pd
from langdetect import detect

import requests
from PIL import Image

from nltk import word_tokenize
from nltk.corpus import stopwords

# %%
# Load the data set to a data frame
df = pd.read_csv('goodreads_100k_books.csv')

# %%
# Set to display all columns in a data frame
pd.set_option('display.max_columns', None)

# %%
# Check the head of the data frame
df.head(1)
# Out:
#                  author bookformat  \
# 0  Laurence M. Hauptman  Hardcover
#
#                                                 desc  \
# 0  Reveals that several hundred thousand Indians ...
#
#                                                genre  \
# 0  History,Military History,Civil War,American Hi...
#
#                                                  img        isbn    isbn13  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...  002914180X  9.78E+12
#
#                                                 link  pages  rating  reviews  \
# 0  https://goodreads.com/book/show/1001053.Betwee...      0    3.52        5
#
#                                                title  totalratings
# 0  Between Two Fires: American Indians in the Civ...            33

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  100000

# %%
# Drop all records for which there is no cover image
df = df.dropna(subset = ['img'])

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  96955

# %%
# Change the data to lower case (except img column)
df = df.apply(lambda x: x.lower() if (isinstance(x, str) and x.name != exclude_column) else x)

# %%
# Limit the records to only those which have 'fantasy' in the genre column
limited_genre = 'fantasy'
df = df[df.genre.str.contains(limited_genre, case = False, na = False, regex = True)]

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  15704

# %%
# Check the head of the data frame
df.head(1)
# Out:
#               author bookformat  \
# 35  Marion Weinstein  Paperback
#
#                                                  desc  \
# 35  Marion Weinstein was one of the first witches ...
#
#                                                 genre  \
# 35  Religion,Wicca,Witchcraft,Spirituality,Nonfict...
#
#                                                   img        isbn    isbn13  \
# 35  https://i.gr-assets.com/images/S/compressed.ph...  1564146383  9.78E+12
#
#                                                  link  pages  rating  reviews  \
# 35  https://goodreads.com/book/show/1001409.Earth_...    224    4.12       14
#
#                                                 title  totalratings
# 35  Earth Magic: A Book of Shadows for Positive Wi...           337

# %%
# Print the number of columns in the data frame
print('The number of columns is: ', len(df.columns))
# Out:
# The number of columns is:  13

# %%
# Split the genre column on columns so that there are individual columns for each genre in the genre column

# Set the maximum number of columns to match the row with the maximum number of genres listed plus 1
max_cols = df.genre.str.count(',').max() + 1
# Split the genre column into multimple columns on the comma using the maximum number of columns specified earlier
split_cols = df.genre.str.split(',', expand = True, n = max_cols)


# Set a naming convention for the new columns (starting with 'genre_' and ending with the number of the column)
new_cols = [f'genre_{col}' for col in split_cols.columns]
split_cols.columns = new_cols

# Add the new columns to the data frame
df = pd.concat([df, split_cols], axis = 1)

# Drop the original genre column
df = df.drop(['genre'], axis = 1)

# %%
# Print the number of columns in the data frame
print('The number of columns is: ', len(df.columns))
# Out:
# The number of columns is:  32

# %%
# Check the head of the data frame
df.head(1)
# Out:
#               author bookformat  \
# 35  Marion Weinstein  Paperback
#
#                                                  desc  \
# 35  Marion Weinstein was one of the first witches ...
#
#                                                   img        isbn    isbn13  \
# 35  https://i.gr-assets.com/images/S/compressed.ph...  1564146383  9.78E+12
#
#                                                  link  pages  rating  reviews  \
# 35  https://goodreads.com/book/show/1001409.Earth_...    224    4.12       14
#
#                                                 title  totalratings   genre_0  \
# 35  Earth Magic: A Book of Shadows for Positive Wi...           337  Religion
#
#    genre_1     genre_2       genre_3     genre_4   genre_5   genre_6  \
# 35   Wicca  Witchcraft  Spirituality  Nonfiction  Religion  Paganism
#
#      genre_7 genre_8  genre_9 genre_10  genre_11 genre_12      genre_13  \
# 35  Religion  Occult  Fantasy    Magic  Religion  Goddess  Spirituality
#
#    genre_14 genre_15 genre_16 genre_17 genre_18 genre_19
# 35  New Age     None     None     None     None     None

# %%
# Check a summary of genre_1 columns unique values
df.genre_1.unique()
# Out:
# array(['Wicca', 'Fiction', 'Comics', 'Romance', 'Short Stories',
#        'Fantasy', 'Poetry', 'Science Fiction', 'Supernatural',
#        'Historical', 'Occult', 'Vampires', 'Young Adult', 'Religion',
#        'Classics', 'Mythology', 'Manga', 'Picture Books',
#        'Historical Fiction', 'Childrens', 'Arthurian', 'Humor', 'Games',
#        'Forgotten Realms', 'World Of Warcraft', 'Art', 'Horror',
#        'Cryptozoology', 'Adult Fiction', 'Bande Dessinée',
#        'Alternate History', 'European Literature', 'Nonfiction',
#        'Heroic Fantasy', 'Space', 'M M Romance', 'Star Wars',
#        'Media Tie In', 'Christian', 'Steampunk', 'Role Playing Games',
#        'Paranormal', 'Star Trek', 'Graphic Novels', 'Apocalyptic',
#        'Sports', 'Angels', 'Sequential Art', 'Gaming', 'Christmas',
#        'Novels', 'Mystery', 'Philosophy', '40k', 'Urban Fantasy',
#        'Paranormal Romance', 'Crime', 'Audiobook', 'Dragonlance',
#        'Romanian Literature', 'Cultural', 'Magical Realism', 'Reference',
#        'Menage', 'Dragons', 'Dystopia', 'World Of Darkness', 'Erotica',
#        'Environment', 'Westerns', 'History', 'Batman',
#        'Historical Romance', 'Babylon 5', 'Doctor Who', 'Time Travel',
#        'Italian Literature', 'Demons', 'Czech Literature', 'Fairies',
#        'Zombies', 'Holiday', 'Polish Literature', 'Fairy Tales', 'LGBT',
#        'Paganism', 'Dungeons and Dragons', 'Witchcraft', 'Adventure',
#        'Tarot', 'Biblical Fiction', 'Cyberpunk', 'Light Novel', 'Aliens',
#        'Anthologies', 'Lesbian', 'School', 'GLBT',
#        'Indonesian Literature', 'Thriller', 'Christian Fiction',
#        'Harlequin', 'Harlequin Blaze', 'Shapeshifters', 'Gamebooks',
#        'Unicorns', 'Astrology', 'Pseudoscience', 'M M Fantasy',
#        'Ghost Stories', 'Plays', 'Asian Literature', None, 'Writing',
#        'Science Fiction Fantasy', 'Music', 'Divination', 'Magick',
#        'Memoir', 'Northern Africa', 'Dark', 'Regency', 'Chick Lit', 'War',
#        'Animals', 'Science', 'Spirituality', 'Ireland', 'Danish',
#        'Sports and Games', 'Mermaids', 'Drama', 'Halloween', 'Russia',
#        'BDSM', 'Novella', 'Werewolves', 'Post Apocalyptic', 'Pirates',
#        'Archaeology', 'Egypt', 'Hinduism', 'Video Games', 'Contemporary',
#        'Folklore', 'Womens Fiction', 'Gothic', 'Buffy The Vampire Slayer',
#        'Interracial Romance', 'Bizarro Fiction', 'Culture', 'Warcraft',
#        'Magic', 'Mathematics', 'Family', 'Buddhism', 'Cinderella',
#        'Middle Grade', 'Eastern Africa', 'Inspirational', 'Lds Fiction',
#        'Judaism', 'Monsters', 'Biography', 'Christian Fantasy',
#        'Dark Fantasy', 'Baseball', 'Astronomy', 'Turkish Literature',
#        'Fan Fiction', 'Chapter Books', 'North American Hi...',
#        'Historical Fantasy', 'Thelema', 'Feminism', 'Hugo Awards',
#        'Drawing', 'Folk Tales', 'Finnish Literature', 'Esoterica',
#        'Transgender', 'Choose Your Own Adventure', 'Witches', 'Jewish',
#        'Fae', 'Science Fiction Romance', 'Metaphysics', 'Biology',
#        'Beauty and The Beast', 'Taoism', 'Language', 'Gay',
#        'Lovecraftian', 'Pulp', 'Maps', 'Horses', 'Crafts', 'India',
#        'Parenting', 'Yaoi', 'Fashion', 'Comedy', 'Marathi', 'Dogs',
#        'Nature', 'Weird Fiction', 'Ghosts', 'Lds', 'Psychology', 'Japan',
#        'Superheroes', 'France', 'Ukrainian Literature', 'Academic',
#        'Africa', 'Romantic Suspense', 'Literature', 'Goddess',
#        'Bulgarian Literature', 'Autobiography', 'Literary Fiction',
#        'China', 'Dinosaurs', 'Essays', 'Category Romance', 'Wolves',
#        'Photography', 'Dc Comics', 'Time Travel Romance', 'Travel',
#        'Retellings', 'Film', 'Criticism', 'Erotic Paranormal Romance',
#        'Zimbabwe', 'Erotic Romance', 'Marvel', 'Cozy Mystery',
#        'Military Fiction', 'Plus Size', 'Greek Mythology', 'Love',
#        'Greece', 'Gardening', 'Alchemy', 'Manhwa', 'Banned Books',
#        'Scotland', 'Medieval', 'Storytime', 'Humanities', 'Cartography',
#        'Ethiopia', 'Cookbooks', 'Literary Criticism', 'Wonder Woman',
#        'Webcomic', 'Queer', 'Anthropomorphic', 'Cats', 'Computer Science',
#        'Sword and Sorcery', 'Goth', 'Reverse Harem',
#        'Hungarian Literature', 'Swedish Literature', 'M M M',
#        'M M Aliens', 'New Adult', 'Knitting', 'Australia',
#        'Speculative Fiction'], dtype=object)

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  15704

# %%
# Remove fan fiction and graphic mediums from the records

# Define a list of genres to exclude from the data
exclude_genres = ['fan fiction', 'comics', 'sequential art', 'anthologies', 'role playing games', 'manga', 'graphic novel', 'graphic novels', 
                  'comic', 'dungeons and dragons', 'webcomic', 'fan fiction', 'children', 'childrens', 'nonfiction', 'Childrens', 'childrens', 'Video Games', 
                  'video games', 'Christmas', 'christmas', 'Anthologies', 'anthologies', 'Nonfiction', 'nonfiction', 'Tv', 'tv', 'Historical Fiction', 'historical fiction', 
                  'historical']

# Use the list of excluded genres to remove records that contain those genres anywhere
df = df[~df.map(lambda x: x in exclude_genres).any(axis = 1)]

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  10586

# %%
# Check the head of the data frame
df.head(3)
# Out:
#                                     author bookformat  \
# 58   Chuck Dixon,Scott McDaniel,Karl Story  Paperback
# 67                       Eliezer Yudkowsky      ebook
# 111                            Robert Reed  Paperback
#
#                                                   desc  \
# 58   Growing up as Robin the Boy Wonder, Dick Grays...
# 67   Harry Potter and the Methods of Rationality is...
# 111  The Ship has traveled the universe for longer ...
#
#                                                    img        isbn    isbn13  \
# 58   https://i.gr-assets.com/images/S/compressed.ph...  1563896133  9.78E+12
# 67   https://i.gr-assets.com/images/S/compressed.ph...         NaN       NaN
# 111  https://i.gr-assets.com/images/S/compressed.ph...   812566572  9.78E+12
#
#                                                   link  pages  rating  \
# 58   https://goodreads.com/book/show/1001530.Nightwing    208    3.95
# 67   https://goodreads.com/book/show/10016013-harry...   2184    4.40
# 111      https://goodreads.com/book/show/100208.Marrow    512    3.82
#
#      reviews                                        title  totalratings  \
# 58        17                  Nightwing: Love and Bullets           357
# 67      1414  Harry Potter and the Methods of Rationality         14293
# 111      110                                       Marrow          2051
#
#              genre_0  genre_1         genre_2         genre_3  \
# 58    Sequential Art   Comics  Sequential Art  Graphic Novels
# 67           Fantasy  Fiction     Fan Fiction      Philosophy
# 111  Science Fiction  Fiction           Space     Space Opera
#
#              genre_4                  genre_5    genre_6          genre_7  \
# 58       Superheroes                Dc Comics  Dc Comics           Batman
# 67   Science Fiction              Young Adult      Humor          Fantasy
# 111          Mystery  Science Fiction Fantasy      Space  Science Fiction
#
#       genre_8          genre_9               genre_10         genre_11  \
# 58     Comics       Comic Book  Graphic Novels Comics           Comics
# 67      Magic       Unfinished              Adventure             None
# 111  Dystopia  Science Fiction   Hard Science Fiction  Science Fiction
#
#         genre_12             genre_13 genre_14 genre_15 genre_16 genre_17  \
# 58   Superheroes              Fiction  Fantasy     None     None     None
# 67          None                 None     None     None     None     None
# 111       Aliens  Speculative Fiction     None     None     None     None
#
#     genre_18 genre_19
# 58      None     None
# 67      None     None
# 111     None     None

# %%
# I want to remove any books that have a language other than English in the description (desc) column

# Define a function to detect the language in the desc column
def detect_language(desc):
    try:
        return detect(desc)
    except:
        return 'unknown'

# Apply the detect language function to the data frame and assign the values to a new column called 'language'    
df['language'] = df.desc.apply(detect_language)

# Select only the rows that contain 'en' (English) in the 'language' column
df = df.loc[df['language'] == 'en'].copy()
# Drop the 'language' column, it is not needed anymore
df = df.drop('language', axis = 1)

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  9676

# %%
df.head(3)
# Out:
#                                     author bookformat  \
# 58   Chuck Dixon,Scott McDaniel,Karl Story  Paperback
# 67                       Eliezer Yudkowsky      ebook
# 111                            Robert Reed  Paperback
#
#                                                   desc  \
# 58   Growing up as Robin the Boy Wonder, Dick Grays...
# 67   Harry Potter and the Methods of Rationality is...
# 111  The Ship has traveled the universe for longer ...
#
#                                                    img        isbn    isbn13  \
# 58   https://i.gr-assets.com/images/S/compressed.ph...  1563896133  9.78E+12
# 67   https://i.gr-assets.com/images/S/compressed.ph...         NaN       NaN
# 111  https://i.gr-assets.com/images/S/compressed.ph...   812566572  9.78E+12
#
#                                                   link  pages  rating  \
# 58   https://goodreads.com/book/show/1001530.Nightwing    208    3.95
# 67   https://goodreads.com/book/show/10016013-harry...   2184    4.40
# 111      https://goodreads.com/book/show/100208.Marrow    512    3.82
#
#      reviews                                        title  totalratings  \
# 58        17                  Nightwing: Love and Bullets           357
# 67      1414  Harry Potter and the Methods of Rationality         14293
# 111      110                                       Marrow          2051
#
#              genre_0  genre_1         genre_2         genre_3  \
# 58    Sequential Art   Comics  Sequential Art  Graphic Novels
# 67           Fantasy  Fiction     Fan Fiction      Philosophy
# 111  Science Fiction  Fiction           Space     Space Opera
#
#              genre_4                  genre_5    genre_6          genre_7  \
# 58       Superheroes                Dc Comics  Dc Comics           Batman
# 67   Science Fiction              Young Adult      Humor          Fantasy
# 111          Mystery  Science Fiction Fantasy      Space  Science Fiction
#
#       genre_8          genre_9               genre_10         genre_11  \
# 58     Comics       Comic Book  Graphic Novels Comics           Comics
# 67      Magic       Unfinished              Adventure             None
# 111  Dystopia  Science Fiction   Hard Science Fiction  Science Fiction
#
#         genre_12             genre_13 genre_14 genre_15 genre_16 genre_17  \
# 58   Superheroes              Fiction  Fantasy     None     None     None
# 67          None                 None     None     None     None     None
# 111       Aliens  Speculative Fiction     None     None     None     None
#
#     genre_18 genre_19
# 58      None     None
# 67      None     None
# 111     None     None

# %%
# Remove all the words from the desc column that are stop words ('the', 'and', 'then', etc.) This makes for easier analysis later

# Create a set of English stopwords
stop_words = set(stopwords.words('english'))

# Define a function to select the keywords from each record desc
def extract_keywords(text):
    tokens = word_tokenize(text)
    keywords = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

    return ' '.join(keywords)


# Apply the keywords function to the desc column, removing all stopwords
df['desc'] = df['desc'].apply(extract_keywords)

# %%
df.head(3)
# Out:
#                                     author bookformat  \
# 58   Chuck Dixon,Scott McDaniel,Karl Story  Paperback
# 67                       Eliezer Yudkowsky      ebook
# 111                            Robert Reed  Paperback
#
#                                                   desc  \
# 58   growing robin boy wonder dick grayson lived li...
# 67   harry potter methods rationality work harry po...
# 111  ship traveled universe longer crew recall true...
#
#                                                    img        isbn    isbn13  \
# 58   https://i.gr-assets.com/images/S/compressed.ph...  1563896133  9.78E+12
# 67   https://i.gr-assets.com/images/S/compressed.ph...         NaN       NaN
# 111  https://i.gr-assets.com/images/S/compressed.ph...   812566572  9.78E+12
#
#                                                   link  pages  rating  \
# 58   https://goodreads.com/book/show/1001530.Nightwing    208    3.95
# 67   https://goodreads.com/book/show/10016013-harry...   2184    4.40
# 111      https://goodreads.com/book/show/100208.Marrow    512    3.82
#
#      reviews                                        title  totalratings  \
# 58        17                  Nightwing: Love and Bullets           357
# 67      1414  Harry Potter and the Methods of Rationality         14293
# 111      110                                       Marrow          2051
#
#              genre_0  genre_1         genre_2         genre_3  \
# 58    Sequential Art   Comics  Sequential Art  Graphic Novels
# 67           Fantasy  Fiction     Fan Fiction      Philosophy
# 111  Science Fiction  Fiction           Space     Space Opera
#
#              genre_4                  genre_5    genre_6          genre_7  \
# 58       Superheroes                Dc Comics  Dc Comics           Batman
# 67   Science Fiction              Young Adult      Humor          Fantasy
# 111          Mystery  Science Fiction Fantasy      Space  Science Fiction
#
#       genre_8          genre_9               genre_10         genre_11  \
# 58     Comics       Comic Book  Graphic Novels Comics           Comics
# 67      Magic       Unfinished              Adventure             None
# 111  Dystopia  Science Fiction   Hard Science Fiction  Science Fiction
#
#         genre_12             genre_13 genre_14 genre_15 genre_16 genre_17  \
# 58   Superheroes              Fiction  Fantasy     None     None     None
# 67          None                 None     None     None     None     None
# 111       Aliens  Speculative Fiction     None     None     None     None
#
#     genre_18 genre_19
# 58      None     None
# 67      None     None
# 111     None     None

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  9676

# %%
# Get statistics for the 'pages' column to show the maximum and minimum number of pages, among other descriptors
df.pages.describe()
# Out:
# count    9676.000000
# mean      259.451840
# std       184.749676
# min         0.000000
# 25%       144.000000
# 50%       255.000000
# 75%       350.000000
# max      5375.000000
# Name: pages, dtype: float64

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  9676

# %%
# Get the new statistics
df.pages.describe()
# Out:
# count    9676.000000
# mean      259.451840
# std       184.749676
# min         0.000000
# 25%       144.000000
# 50%       255.000000
# 75%       350.000000
# max      5375.000000
# Name: pages, dtype: float64

# %%
# Select only records that have less than or equal to 1000 pages
df = df[df.pages <= 1000]

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  9636

# %%
# Get the new statistics for pages
df.pages.describe()
# Out:
# count    9636.000000
# mean      253.669884
# std       149.259148
# min         0.000000
# 25%       144.000000
# 50%       254.000000
# 75%       349.000000
# max      1000.000000
# Name: pages, dtype: float64

# %%
# Describe the number of reviews
df.reviews.describe()
# Out:
# count      9636.000000
# mean        497.014529
# std        2717.485172
# min           0.000000
# 25%          21.000000
# 50%          71.000000
# 75%         235.250000
# max      110042.000000
# Name: reviews, dtype: float64

# %%
# Describe the totalratings column
df.totalratings.describe()
# Out:
# count    9.636000e+03
# mean     8.696948e+03
# std      6.952732e+04
# min      1.000000e+00
# 25%      2.450000e+02
# 50%      9.670000e+02
# 75%      3.320250e+03
# max      3.099689e+06
# Name: totalratings, dtype: float64

# %% [markdown]
# - Count: 8,608
# - Mean: 10,223.42
# - Std (Standard Deviation): 75,466.09
# - Min: 1
# - 25% (Q1): 336
# - 50% (Median or Q2): 1,141
# - 75% (Q3): 3,957.25
# - Max: 3,099,689

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  9636

# %%
# Remove records that have less than 1000 reviews (we want a solid statistical sample)
df = df[df.totalratings > 1000]

# %%
# Check the number of records in the data frame
print('The number of records is: ', len(df))
# Out:
# The number of records is:  4723

# %%
df.totalratings.describe()
# Out:
# count    4.723000e+03
# mean     1.738949e+04
# std      9.856632e+04
# min      1.001000e+03
# 25%      1.785000e+03
# 50%      3.424000e+03
# 75%      8.541000e+03
# max      3.099689e+06
# Name: totalratings, dtype: float64

# %% [markdown]
# - Count: 4,574
# - Mean: 18,907.73
# - Std (Standard Deviation): 102,752.00
# - Min: 1,001
# - 25% (Q1): 1,813.75
# - 50% (Median or Q2): 3,625.00
# - 75% (Q3): 9,113.25
# - Max: 3,099,689

# %%
df.head(2)
# Out:
#                                author bookformat  \
# 111                       Robert Reed  Paperback
# 139  Wu Cheng'en,Arthur Waley,Hu Shih  Paperback
#
#                                                   desc  \
# 111  ship traveled universe longer crew recall true...
# 139  probably popular book history far east classic...
#
#                                                    img       isbn    isbn13  \
# 111  https://i.gr-assets.com/images/S/compressed.ph...  812566572  9.78E+12
# 139  https://i.gr-assets.com/images/S/compressed.ph...  802130860  9.78E+12
#
#                                               link  pages  rating  reviews  \
# 111  https://goodreads.com/book/show/100208.Marrow    512    3.82      110
# 139  https://goodreads.com/book/show/100237.Monkey    306    4.02      552
#
#                                title  totalratings          genre_0  genre_1  \
# 111                           Marrow          2051  Science Fiction  Fiction
# 139  Monkey: The Journey to the West          6147         Classics  Fiction
#
#      genre_2      genre_3  genre_4                  genre_5    genre_6  \
# 111    Space  Space Opera  Mystery  Science Fiction Fantasy      Space
# 139  Fantasy     Cultural    China                  Fantasy  Mythology
#
#               genre_7             genre_8          genre_9  \
# 111   Science Fiction            Dystopia  Science Fiction
# 139  Asian Literature  Chinese Literature       Literature
#
#                  genre_10         genre_11 genre_12             genre_13  \
# 111  Hard Science Fiction  Science Fiction   Aliens  Speculative Fiction
# 139              Cultural             Asia   Novels            Adventure
#
#     genre_14 genre_15 genre_16 genre_17 genre_18 genre_19
# 111     None     None     None     None     None     None
# 139     None     None     None     None     None     None

# %%
len(df)
# Out:
# 4723

# %%
df['multiple_img'] = df.img.apply(lambda x: len(x.split()) > 1 if isinstance(x, str) else False)

# %%
df.multiple_img.unique()
# Out:
# array([False])

# %%
df = df.drop(['multiple_img'], axis = 1)

# %%
len(df.img.unique())
# Out:
# 4723

# %%
df.head()
# Out:
#                                author      bookformat  \
# 111                       Robert Reed       Paperback
# 139  Wu Cheng'en,Arthur Waley,Hu Shih       Paperback
# 160                    Beth Fantaskey       Hardcover
# 236                   Lindsay Buroker  Kindle Edition
# 276                       Larry Niven       Paperback
#
#                                                   desc  \
# 111  ship traveled universe longer crew recall true...
# 139  probably popular book history far east classic...
# 160  one thing find vampire princess whole thing ac...
# 236  adventure starts imperial law enforcer amarant...
# 276  phssthpok pak traveling thousand years mission...
#
#                                                    img       isbn    isbn13  \
# 111  https://i.gr-assets.com/images/S/compressed.ph...  812566572  9.78E+12
# 139  https://i.gr-assets.com/images/S/compressed.ph...  802130860  9.78E+12
# 160  https://i.gr-assets.com/images/S/compressed.ph...  547393091  9.78E+12
# 236  https://i.gr-assets.com/images/S/compressed.ph...        NaN       NaN
# 276  https://i.gr-assets.com/images/S/compressed.ph...  345353129  9.78E+12
#
#                                                   link  pages  rating  \
# 111      https://goodreads.com/book/show/100208.Marrow    512    3.82
# 139      https://goodreads.com/book/show/100237.Monkey    306    4.02
# 160  https://goodreads.com/book/show/10025007-jessi...    309    3.90
# 236  https://goodreads.com/book/show/10031259-the-e...    324    4.04
# 276   https://goodreads.com/book/show/100344.Protector    224    4.07
#
#      reviews                            title  totalratings          genre_0  \
# 111      110                           Marrow          2051  Science Fiction
# 139      552  Monkey: The Journey to the West          6147         Classics
# 160      853      Jessica Rules the Dark Side          9807       Paranormal
# 236     1378               The Emperor's Edge         13185          Fantasy
# 276      252                        Protector          9596  Science Fiction
#
#              genre_1      genre_2      genre_3                  genre_4  \
# 111          Fiction        Space  Space Opera                  Mystery
# 139          Fiction      Fantasy     Cultural                    China
# 160         Vampires  Young Adult      Romance                  Fantasy
# 236  Science Fiction    Steampunk      Mystery                  Fiction
# 276          Fiction        Space  Space Opera  Science Fiction Fantasy
#
#                      genre_5    genre_6           genre_7             genre_8  \
# 111  Science Fiction Fantasy      Space   Science Fiction            Dystopia
# 139                  Fantasy  Mythology  Asian Literature  Chinese Literature
# 160               Paranormal    Fantasy           Romance  Paranormal Romance
# 236                Adventure    Fantasy             Magic     Science Fiction
# 276                    Space     Novels   Science Fiction              Aliens
#
#              genre_9              genre_10             genre_11  \
# 111  Science Fiction  Hard Science Fiction      Science Fiction
# 139       Literature              Cultural                 Asia
# 160          Fantasy          Supernatural              Fantasy
# 236          Romance                 Adult              Fantasy
# 276  Science Fiction  Hard Science Fiction  Speculative Fiction
#
#           genre_12             genre_13 genre_14 genre_15 genre_16 genre_17  \
# 111         Aliens  Speculative Fiction     None     None     None     None
# 139         Novels            Adventure     None     None     None     None
# 160  Urban Fantasy              Fiction  Mystery     None     None     None
# 236  Urban Fantasy                 None     None     None     None     None
# 276      Audiobook                 None     None     None     None     None
#
#     genre_18 genre_19
# 111     None     None
# 139     None     None
# 160     None     None
# 236     None     None
# 276     None     None

# %% [markdown]
# We want to add the cover images now that the sample is smaller. They can be analyzed later.

# %%
def download_images_and_process(df, url_column, output_folder):
    total_processed = 0  # Initialize a counter for total records processed

    for index, row in df.iterrows():
        image_url = row[url_column]
        response = requests.get(image_url)

        if response.status_code == 200:
            try:
                # Downloaded image file path
                file_path = f'{output_folder}/image_{index}.jpg'

                # Save the image file
                with open(file_path, 'wb') as file:
                    file.write(response.content)

                # Image processing
                image = Image.open(file_path)

                # Convert the image to RGB
                image = image.convert('RGB')

                # Resize the image to a consistent size (e.g., 100x100 pixels)
                image = image.resize((100, 100))
                
                # Save the processed image
                processed_file_path = f'{output_folder}/processed_image_{index}.jpg'
                image.save(processed_file_path)

                print(f'Image {index} downloaded and processed successfully. Saved to {processed_file_path}')

                # Update DataFrame with processed image path
                df.at[index, 'cover_image'] = processed_file_path

                # Increment the counter
                total_processed += 1

                # Print the total number of records processed at each iteration
                print(f'Total number of records processed so far: {total_processed}')

            except Exception as e:
                print(f'Error processing image {index}: {str(e)}')

        else:
            print(f'Failed to download image {index}. Status code: {response.status_code}')

    print(f'Total number of records processed: {total_processed}')

# %%
output_folder = 'cover_images'

url_column = 'img'

download_images_and_process(df, url_column, output_folder)
# Out:
# Image 111 downloaded and processed successfully. Saved to cover_images/processed_image_111.jpg
# Total number of records processed so far: 1
# Image 139 downloaded and processed successfully. Saved to cover_images/processed_image_139.jpg
# Total number of records processed so far: 2
# Image 160 downloaded and processed successfully. Saved to cover_images/processed_image_160.jpg
# Total number of records processed so far: 3
# Image 236 downloaded and processed successfully. Saved to cover_images/processed_image_236.jpg
# Total number of records processed so far: 4
# Image 276 downloaded and processed successfully. Saved to cover_images/processed_image_276.jpg
# Total number of records processed so far: 5
# Image 286 downloaded and processed successfully. Saved to cover_images/processed_image_286.jpg
# Total number of records processed so far: 6
# Image 301 downloaded and processed successfully. Saved to cover_images/processed_image_301.jpg
# Total number of records processed so far: 7
# Image 303 downloaded and processed successfully. Saved to cover_images/processed_image_303.jpg
# Total number of records processed so far: 8
# Image 309 downloaded and processed successfully. Saved to cover_images/processed_image_309.jpg
# Total number of records processed so far: 9
# Image 328 downloaded and processed successfully. Saved to cover_images/processed_image_328.jpg
# Total number of records processed so far: 10
# Image 340 downloaded and processed successfully. Saved to cover_images/processed_image_340.jpg
# Total number of records processed so far: 11
# Image 349 downloaded and processed successfully. Saved to cover_images/processed_image_349.jpg
# Total number of records processed so far: 12
# Image 384 downloaded and processed successfully. Saved to cover_images/processed_image_384.jpg
# Total number of records processed so far: 13
# Image 452 downloaded and processed successfully. Saved to cover_images/processed_image_452.jpg
# Total number of records processed so far: 14
# Image 455 downloaded and processed successfully. Saved to cover_images/processed_image_455.jpg
# Total number of records processed so far: 15
# Image 456 downloaded and processed successfully. Saved to cover_images/processed_image_456.jpg
# Total number of records processed so far: 16
# Image 540 downloaded and processed successfully. Saved to cover_images/processed_image_540.jpg
# Total number of records processed so far: 17
# Image 656 downloaded and processed successfully. Saved to cover_images/processed_image_656.jpg
# Total number of records processed so far: 18
# Image 664 downloaded and processed successfully. Saved to cover_images/processed_image_664.jpg
# Total number of records processed so far: 19
# Image 693 downloaded and processed successfully. Saved to cover_images/processed_image_693.jpg
# Total number of records processed so far: 20
# Image 721 downloaded and processed successfully. Saved to cover_images/processed_image_721.jpg
# Total number of records processed so far: 21
# Image 722 downloaded and processed successfully. Saved to cover_images/processed_image_722.jpg
# Total number of records processed so far: 22
# Image 736 downloaded and processed successfully. Saved to cover_images/processed_image_736.jpg
# Total number of records processed so far: 23
# Image 804 downloaded and processed successfully. Saved to cover_images/processed_image_804.jpg
# Total number of records processed so far: 24
# Image 807 downloaded and processed successfully. Saved to cover_images/processed_image_807.jpg
# Total number of records processed so far: 25
# Image 844 downloaded and processed successfully. Saved to cover_images/processed_image_844.jpg
# Total number of records processed so far: 26
# Image 857 downloaded and processed successfully. Saved to cover_images/processed_image_857.jpg
# Total number of records processed so far: 27
# Image 906 downloaded and processed successfully. Saved to cover_images/processed_image_906.jpg
# Total number of records processed so far: 28
# Image 922 downloaded and processed successfully. Saved to cover_images/processed_image_922.jpg
# Total number of records processed so far: 29
# Image 954 downloaded and processed successfully. Saved to cover_images/processed_image_954.jpg
# Total number of records processed so far: 30
# Image 980 downloaded and processed successfully. Saved to cover_images/processed_image_980.jpg
# Total number of records processed so far: 31
# Image 1049 downloaded and processed successfully. Saved to cover_images/processed_image_1049.jpg
# Total number of records processed so far: 32
# Image 1062 downloaded and processed successfully. Saved to cover_images/processed_image_1062.jpg
# Total number of records processed so far: 33
# Image 1120 downloaded and processed successfully. Saved to cover_images/processed_image_1120.jpg
# Total number of records processed so far: 34
# Image 1161 downloaded and processed successfully. Saved to cover_images/processed_image_1161.jpg
# Total number of records processed so far: 35
# Image 1164 downloaded and processed successfully. Saved to cover_images/processed_image_1164.jpg
# Total number of records processed so far: 36
# Image 1217 downloaded and processed successfully. Saved to cover_images/processed_image_1217.jpg
# Total number of records processed so far: 37
# Image 1241 downloaded and processed successfully. Saved to cover_images/processed_image_1241.jpg
# Total number of records processed so far: 38
# Image 1244 downloaded and processed successfully. Saved to cover_images/processed_image_1244.jpg
# Total number of records processed so far: 39
# Image 1253 downloaded and processed successfully. Saved to cover_images/processed_image_1253.jpg
# Total number of records processed so far: 40
# Image 1259 downloaded and processed successfully. Saved to cover_images/processed_image_1259.jpg
# Total number of records processed so far: 41
# Image 1284 downloaded and processed successfully. Saved to cover_images/processed_image_1284.jpg
# Total number of records processed so far: 42
# Image 1396 downloaded and processed successfully. Saved to cover_images/processed_image_1396.jpg
# Total number of records processed so far: 43
# Image 1399 downloaded and processed successfully. Saved to cover_images/processed_image_1399.jpg
# Total number of records processed so far: 44
# Image 1428 downloaded and processed successfully. Saved to cover_images/processed_image_1428.jpg
# Total number of records processed so far: 45
# Image 1454 downloaded and processed successfully. Saved to cover_images/processed_image_1454.jpg
# Total number of records processed so far: 46
# Image 1488 downloaded and processed successfully. Saved to cover_images/processed_image_1488.jpg
# Total number of records processed so far: 47
# Image 1508 downloaded and processed successfully. Saved to cover_images/processed_image_1508.jpg
# Total number of records processed so far: 48
# Image 1553 downloaded and processed successfully. Saved to cover_images/processed_image_1553.jpg
# Total number of records processed so far: 49
# Image 1647 downloaded and processed successfully. Saved to cover_images/processed_image_1647.jpg
# Total number of records processed so far: 50
# Image 1682 downloaded and processed successfully. Saved to cover_images/processed_image_1682.jpg
# Total number of records processed so far: 51
# Image 1704 downloaded and processed successfully. Saved to cover_images/processed_image_1704.jpg
# Total number of records processed so far: 52
# Image 1843 downloaded and processed successfully. Saved to cover_images/processed_image_1843.jpg
# Total number of records processed so far: 53
# Image 1844 downloaded and processed successfully. Saved to cover_images/processed_image_1844.jpg
# Total number of records processed so far: 54
# Image 1904 downloaded and processed successfully. Saved to cover_images/processed_image_1904.jpg
# Total number of records processed so far: 55
# Image 2039 downloaded and processed successfully. Saved to cover_images/processed_image_2039.jpg
# Total number of records processed so far: 56
# Image 2052 downloaded and processed successfully. Saved to cover_images/processed_image_2052.jpg
# Total number of records processed so far: 57
# Image 2063 downloaded and processed successfully. Saved to cover_images/processed_image_2063.jpg
# Total number of records processed so far: 58
# Image 2079 downloaded and processed successfully. Saved to cover_images/processed_image_2079.jpg
# Total number of records processed so far: 59
# Image 2080 downloaded and processed successfully. Saved to cover_images/processed_image_2080.jpg
# Total number of records processed so far: 60
# Image 2094 downloaded and processed successfully. Saved to cover_images/processed_image_2094.jpg
# Total number of records processed so far: 61
# Image 2128 downloaded and processed successfully. Saved to cover_images/processed_image_2128.jpg
# Total number of records processed so far: 62
# Image 2136 downloaded and processed successfully. Saved to cover_images/processed_image_2136.jpg
# Total number of records processed so far: 63
# Image 2146 downloaded and processed successfully. Saved to cover_images/processed_image_2146.jpg
# Total number of records processed so far: 64
# Image 2175 downloaded and processed successfully. Saved to cover_images/processed_image_2175.jpg
# Total number of records processed so far: 65
# Image 2263 downloaded and processed successfully. Saved to cover_images/processed_image_2263.jpg
# Total number of records processed so far: 66
# Image 2296 downloaded and processed successfully. Saved to cover_images/processed_image_2296.jpg
# Total number of records processed so far: 67
# Image 2297 downloaded and processed successfully. Saved to cover_images/processed_image_2297.jpg
# Total number of records processed so far: 68
# Image 2298 downloaded and processed successfully. Saved to cover_images/processed_image_2298.jpg
# Total number of records processed so far: 69
# Image 2318 downloaded and processed successfully. Saved to cover_images/processed_image_2318.jpg
# Total number of records processed so far: 70
# Image 2363 downloaded and processed successfully. Saved to cover_images/processed_image_2363.jpg
# Total number of records processed so far: 71
# Image 2383 downloaded and processed successfully. Saved to cover_images/processed_image_2383.jpg
# Total number of records processed so far: 72
# Image 2412 downloaded and processed successfully. Saved to cover_images/processed_image_2412.jpg
# Total number of records processed so far: 73
# Image 2417 downloaded and processed successfully. Saved to cover_images/processed_image_2417.jpg
# Total number of records processed so far: 74
# Image 2418 downloaded and processed successfully. Saved to cover_images/processed_image_2418.jpg
# Total number of records processed so far: 75
# Image 2468 downloaded and processed successfully. Saved to cover_images/processed_image_2468.jpg
# Total number of records processed so far: 76
# Image 2490 downloaded and processed successfully. Saved to cover_images/processed_image_2490.jpg
# Total number of records processed so far: 77
# Image 2514 downloaded and processed successfully. Saved to cover_images/processed_image_2514.jpg
# Total number of records processed so far: 78
# Image 2531 downloaded and processed successfully. Saved to cover_images/processed_image_2531.jpg
# Total number of records processed so far: 79
# Image 2556 downloaded and processed successfully. Saved to cover_images/processed_image_2556.jpg
# Total number of records processed so far: 80
# Image 2634 downloaded and processed successfully. Saved to cover_images/processed_image_2634.jpg
# Total number of records processed so far: 81
# Image 2644 downloaded and processed successfully. Saved to cover_images/processed_image_2644.jpg
# Total number of records processed so far: 82
# Image 2655 downloaded and processed successfully. Saved to cover_images/processed_image_2655.jpg
# Total number of records processed so far: 83
# Image 2657 downloaded and processed successfully. Saved to cover_images/processed_image_2657.jpg
# Total number of records processed so far: 84
# Image 2663 downloaded and processed successfully. Saved to cover_images/processed_image_2663.jpg
# Total number of records processed so far: 85
# Image 2664 downloaded and processed successfully. Saved to cover_images/processed_image_2664.jpg
# Total number of records processed so far: 86
# Image 2668 downloaded and processed successfully. Saved to cover_images/processed_image_2668.jpg
# Total number of records processed so far: 87
# Image 2688 downloaded and processed successfully. Saved to cover_images/processed_image_2688.jpg
# Total number of records processed so far: 88
# Image 2693 downloaded and processed successfully. Saved to cover_images/processed_image_2693.jpg
# Total number of records processed so far: 89
# Image 2708 downloaded and processed successfully. Saved to cover_images/processed_image_2708.jpg
# Total number of records processed so far: 90
# Image 2716 downloaded and processed successfully. Saved to cover_images/processed_image_2716.jpg
# Total number of records processed so far: 91
# Image 2721 downloaded and processed successfully. Saved to cover_images/processed_image_2721.jpg
# Total number of records processed so far: 92
# Image 2723 downloaded and processed successfully. Saved to cover_images/processed_image_2723.jpg
# Total number of records processed so far: 93
# Image 2735 downloaded and processed successfully. Saved to cover_images/processed_image_2735.jpg
# Total number of records processed so far: 94
# Image 2749 downloaded and processed successfully. Saved to cover_images/processed_image_2749.jpg
# Total number of records processed so far: 95
# Image 2765 downloaded and processed successfully. Saved to cover_images/processed_image_2765.jpg
# Total number of records processed so far: 96
# Image 2772 downloaded and processed successfully. Saved to cover_images/processed_image_2772.jpg
# Total number of records processed so far: 97
# Image 2773 downloaded and processed successfully. Saved to cover_images/processed_image_2773.jpg
# Total number of records processed so far: 98
# Image 2782 downloaded and processed successfully. Saved to cover_images/processed_image_2782.jpg
# Total number of records processed so far: 99
# Image 2789 downloaded and processed successfully. Saved to cover_images/processed_image_2789.jpg
# Total number of records processed so far: 100
# Image 2796 downloaded and processed successfully. Saved to cover_images/processed_image_2796.jpg
# Total number of records processed so far: 101
# Image 2873 downloaded and processed successfully. Saved to cover_images/processed_image_2873.jpg
# Total number of records processed so far: 102
# Image 2901 downloaded and processed successfully. Saved to cover_images/processed_image_2901.jpg
# Total number of records processed so far: 103
# Image 2907 downloaded and processed successfully. Saved to cover_images/processed_image_2907.jpg
# Total number of records processed so far: 104
# Image 2952 downloaded and processed successfully. Saved to cover_images/processed_image_2952.jpg
# Total number of records processed so far: 105
# Image 2987 downloaded and processed successfully. Saved to cover_images/processed_image_2987.jpg
# Total number of records processed so far: 106
# Image 2991 downloaded and processed successfully. Saved to cover_images/processed_image_2991.jpg
# Total number of records processed so far: 107
# Image 3032 downloaded and processed successfully. Saved to cover_images/processed_image_3032.jpg
# Total number of records processed so far: 108
# Image 3043 downloaded and processed successfully. Saved to cover_images/processed_image_3043.jpg
# Total number of records processed so far: 109
# Image 3054 downloaded and processed successfully. Saved to cover_images/processed_image_3054.jpg
# Total number of records processed so far: 110
# Image 3070 downloaded and processed successfully. Saved to cover_images/processed_image_3070.jpg
# Total number of records processed so far: 111
# Image 3074 downloaded and processed successfully. Saved to cover_images/processed_image_3074.jpg
# Total number of records processed so far: 112
# Image 3076 downloaded and processed successfully. Saved to cover_images/processed_image_3076.jpg
# Total number of records processed so far: 113
# Image 3109 downloaded and processed successfully. Saved to cover_images/processed_image_3109.jpg
# Total number of records processed so far: 114
# Image 3146 downloaded and processed successfully. Saved to cover_images/processed_image_3146.jpg
# Total number of records processed so far: 115
# Image 3154 downloaded and processed successfully. Saved to cover_images/processed_image_3154.jpg
# Total number of records processed so far: 116
# Image 3174 downloaded and processed successfully. Saved to cover_images/processed_image_3174.jpg
# Total number of records processed so far: 117
# Image 3192 downloaded and processed successfully. Saved to cover_images/processed_image_3192.jpg
# Total number of records processed so far: 118
# Image 3194 downloaded and processed successfully. Saved to cover_images/processed_image_3194.jpg
# Total number of records processed so far: 119
# Image 3196 downloaded and processed successfully. Saved to cover_images/processed_image_3196.jpg
# Total number of records processed so far: 120
# Image 3197 downloaded and processed successfully. Saved to cover_images/processed_image_3197.jpg
# Total number of records processed so far: 121
# Image 3211 downloaded and processed successfully. Saved to cover_images/processed_image_3211.jpg
# Total number of records processed so far: 122
# Image 3214 downloaded and processed successfully. Saved to cover_images/processed_image_3214.jpg
# Total number of records processed so far: 123
# Image 3215 downloaded and processed successfully. Saved to cover_images/processed_image_3215.jpg
# Total number of records processed so far: 124
# Image 3237 downloaded and processed successfully. Saved to cover_images/processed_image_3237.jpg
# Total number of records processed so far: 125
# Image 3240 downloaded and processed successfully. Saved to cover_images/processed_image_3240.jpg
# Total number of records processed so far: 126
# Image 3252 downloaded and processed successfully. Saved to cover_images/processed_image_3252.jpg
# Total number of records processed so far: 127
# Image 3258 downloaded and processed successfully. Saved to cover_images/processed_image_3258.jpg
# Total number of records processed so far: 128
# Image 3261 downloaded and processed successfully. Saved to cover_images/processed_image_3261.jpg
# Total number of records processed so far: 129
# Image 3279 downloaded and processed successfully. Saved to cover_images/processed_image_3279.jpg
# Total number of records processed so far: 130
# Image 3287 downloaded and processed successfully. Saved to cover_images/processed_image_3287.jpg
# Total number of records processed so far: 131
# Image 3288 downloaded and processed successfully. Saved to cover_images/processed_image_3288.jpg
# Total number of records processed so far: 132
# Image 3290 downloaded and processed successfully. Saved to cover_images/processed_image_3290.jpg
# Total number of records processed so far: 133
# Image 3302 downloaded and processed successfully. Saved to cover_images/processed_image_3302.jpg
# Total number of records processed so far: 134
# Image 3311 downloaded and processed successfully. Saved to cover_images/processed_image_3311.jpg
# Total number of records processed so far: 135
# Image 3313 downloaded and processed successfully. Saved to cover_images/processed_image_3313.jpg
# Total number of records processed so far: 136
# Image 3321 downloaded and processed successfully. Saved to cover_images/processed_image_3321.jpg
# Total number of records processed so far: 137
# Image 3373 downloaded and processed successfully. Saved to cover_images/processed_image_3373.jpg
# Total number of records processed so far: 138
# Image 3374 downloaded and processed successfully. Saved to cover_images/processed_image_3374.jpg
# Total number of records processed so far: 139
# Image 3376 downloaded and processed successfully. Saved to cover_images/processed_image_3376.jpg
# Total number of records processed so far: 140
# Image 3412 downloaded and processed successfully. Saved to cover_images/processed_image_3412.jpg
# Total number of records processed so far: 141
# Image 3441 downloaded and processed successfully. Saved to cover_images/processed_image_3441.jpg
# Total number of records processed so far: 142
# Image 3471 downloaded and processed successfully. Saved to cover_images/processed_image_3471.jpg
# Total number of records processed so far: 143
# Image 3480 downloaded and processed successfully. Saved to cover_images/processed_image_3480.jpg
# Total number of records processed so far: 144
# Image 3481 downloaded and processed successfully. Saved to cover_images/processed_image_3481.jpg
# Total number of records processed so far: 145
# Image 3498 downloaded and processed successfully. Saved to cover_images/processed_image_3498.jpg
# Total number of records processed so far: 146
# Image 3510 downloaded and processed successfully. Saved to cover_images/processed_image_3510.jpg
# Total number of records processed so far: 147
# Image 3511 downloaded and processed successfully. Saved to cover_images/processed_image_3511.jpg
# Total number of records processed so far: 148
# Image 3514 downloaded and processed successfully. Saved to cover_images/processed_image_3514.jpg
# Total number of records processed so far: 149
# Image 3519 downloaded and processed successfully. Saved to cover_images/processed_image_3519.jpg
# Total number of records processed so far: 150
# Image 3523 downloaded and processed successfully. Saved to cover_images/processed_image_3523.jpg
# Total number of records processed so far: 151
# Image 3530 downloaded and processed successfully. Saved to cover_images/processed_image_3530.jpg
# Total number of records processed so far: 152
# Image 3559 downloaded and processed successfully. Saved to cover_images/processed_image_3559.jpg
# Total number of records processed so far: 153
# Image 3587 downloaded and processed successfully. Saved to cover_images/processed_image_3587.jpg
# Total number of records processed so far: 154
# Image 3658 downloaded and processed successfully. Saved to cover_images/processed_image_3658.jpg
# Total number of records processed so far: 155
# Image 3660 downloaded and processed successfully. Saved to cover_images/processed_image_3660.jpg
# Total number of records processed so far: 156
# Image 3682 downloaded and processed successfully. Saved to cover_images/processed_image_3682.jpg
# Total number of records processed so far: 157
# Image 3689 downloaded and processed successfully. Saved to cover_images/processed_image_3689.jpg
# Total number of records processed so far: 158
# Image 3698 downloaded and processed successfully. Saved to cover_images/processed_image_3698.jpg
# Total number of records processed so far: 159
# Image 3766 downloaded and processed successfully. Saved to cover_images/processed_image_3766.jpg
# Total number of records processed so far: 160
# Image 3769 downloaded and processed successfully. Saved to cover_images/processed_image_3769.jpg
# Total number of records processed so far: 161
# Image 3777 downloaded and processed successfully. Saved to cover_images/processed_image_3777.jpg
# Total number of records processed so far: 162
# Image 3855 downloaded and processed successfully. Saved to cover_images/processed_image_3855.jpg
# Total number of records processed so far: 163
# Image 3915 downloaded and processed successfully. Saved to cover_images/processed_image_3915.jpg
# Total number of records processed so far: 164
# Image 3916 downloaded and processed successfully. Saved to cover_images/processed_image_3916.jpg
# Total number of records processed so far: 165
# Image 3939 downloaded and processed successfully. Saved to cover_images/processed_image_3939.jpg
# Total number of records processed so far: 166
# Image 3962 downloaded and processed successfully. Saved to cover_images/processed_image_3962.jpg
# Total number of records processed so far: 167
# Image 4015 downloaded and processed successfully. Saved to cover_images/processed_image_4015.jpg
# Total number of records processed so far: 168
# Image 4018 downloaded and processed successfully. Saved to cover_images/processed_image_4018.jpg
# Total number of records processed so far: 169
# Image 4035 downloaded and processed successfully. Saved to cover_images/processed_image_4035.jpg
# Total number of records processed so far: 170
# Image 4068 downloaded and processed successfully. Saved to cover_images/processed_image_4068.jpg
# Total number of records processed so far: 171
# Image 4144 downloaded and processed successfully. Saved to cover_images/processed_image_4144.jpg
# Total number of records processed so far: 172
# Image 4161 downloaded and processed successfully. Saved to cover_images/processed_image_4161.jpg
# Total number of records processed so far: 173
# Image 4188 downloaded and processed successfully. Saved to cover_images/processed_image_4188.jpg
# Total number of records processed so far: 174
# Image 4262 downloaded and processed successfully. Saved to cover_images/processed_image_4262.jpg
# Total number of records processed so far: 175
# Image 4264 downloaded and processed successfully. Saved to cover_images/processed_image_4264.jpg
# Total number of records processed so far: 176
# Image 4265 downloaded and processed successfully. Saved to cover_images/processed_image_4265.jpg
# Total number of records processed so far: 177
# Image 4266 downloaded and processed successfully. Saved to cover_images/processed_image_4266.jpg
# Total number of records processed so far: 178
# Image 4268 downloaded and processed successfully. Saved to cover_images/processed_image_4268.jpg
# Total number of records processed so far: 179
# Image 4270 downloaded and processed successfully. Saved to cover_images/processed_image_4270.jpg
# Total number of records processed so far: 180
# Image 4272 downloaded and processed successfully. Saved to cover_images/processed_image_4272.jpg
# Total number of records processed so far: 181
# Image 4305 downloaded and processed successfully. Saved to cover_images/processed_image_4305.jpg
# Total number of records processed so far: 182
# Image 4323 downloaded and processed successfully. Saved to cover_images/processed_image_4323.jpg
# Total number of records processed so far: 183
# Image 4405 downloaded and processed successfully. Saved to cover_images/processed_image_4405.jpg
# Total number of records processed so far: 184
# Image 4408 downloaded and processed successfully. Saved to cover_images/processed_image_4408.jpg
# Total number of records processed so far: 185
# Image 4427 downloaded and processed successfully. Saved to cover_images/processed_image_4427.jpg
# Total number of records processed so far: 186
# Image 4474 downloaded and processed successfully. Saved to cover_images/processed_image_4474.jpg
# Total number of records processed so far: 187
# Image 4503 downloaded and processed successfully. Saved to cover_images/processed_image_4503.jpg
# Total number of records processed so far: 188
# Image 4507 downloaded and processed successfully. Saved to cover_images/processed_image_4507.jpg
# Total number of records processed so far: 189
# Image 4520 downloaded and processed successfully. Saved to cover_images/processed_image_4520.jpg
# Total number of records processed so far: 190
# Image 4555 downloaded and processed successfully. Saved to cover_images/processed_image_4555.jpg
# Total number of records processed so far: 191
# Image 4641 downloaded and processed successfully. Saved to cover_images/processed_image_4641.jpg
# Total number of records processed so far: 192
# Image 4660 downloaded and processed successfully. Saved to cover_images/processed_image_4660.jpg
# Total number of records processed so far: 193
# Image 4674 downloaded and processed successfully. Saved to cover_images/processed_image_4674.jpg
# Total number of records processed so far: 194
# Image 4676 downloaded and processed successfully. Saved to cover_images/processed_image_4676.jpg
# Total number of records processed so far: 195
# Image 4689 downloaded and processed successfully. Saved to cover_images/processed_image_4689.jpg
# Total number of records processed so far: 196
# Image 4730 downloaded and processed successfully. Saved to cover_images/processed_image_4730.jpg
# Total number of records processed so far: 197
# Image 4735 downloaded and processed successfully. Saved to cover_images/processed_image_4735.jpg
# Total number of records processed so far: 198
# Image 4755 downloaded and processed successfully. Saved to cover_images/processed_image_4755.jpg
# Total number of records processed so far: 199
# Image 4809 downloaded and processed successfully. Saved to cover_images/processed_image_4809.jpg
# Total number of records processed so far: 200
# Image 4814 downloaded and processed successfully. Saved to cover_images/processed_image_4814.jpg
# Total number of records processed so far: 201
# Image 4855 downloaded and processed successfully. Saved to cover_images/processed_image_4855.jpg
# Total number of records processed so far: 202
# Image 4863 downloaded and processed successfully. Saved to cover_images/processed_image_4863.jpg
# Total number of records processed so far: 203
# Image 4909 downloaded and processed successfully. Saved to cover_images/processed_image_4909.jpg
# Total number of records processed so far: 204
# Image 4930 downloaded and processed successfully. Saved to cover_images/processed_image_4930.jpg
# Total number of records processed so far: 205
# Image 4940 downloaded and processed successfully. Saved to cover_images/processed_image_4940.jpg
# Total number of records processed so far: 206
# Image 4941 downloaded and processed successfully. Saved to cover_images/processed_image_4941.jpg
# Total number of records processed so far: 207
# Image 5009 downloaded and processed successfully. Saved to cover_images/processed_image_5009.jpg
# Total number of records processed so far: 208
# Image 5033 downloaded and processed successfully. Saved to cover_images/processed_image_5033.jpg
# Total number of records processed so far: 209
# Image 5056 downloaded and processed successfully. Saved to cover_images/processed_image_5056.jpg
# Total number of records processed so far: 210
# Image 5103 downloaded and processed successfully. Saved to cover_images/processed_image_5103.jpg
# Total number of records processed so far: 211
# Image 5108 downloaded and processed successfully. Saved to cover_images/processed_image_5108.jpg
# Total number of records processed so far: 212
# Image 5110 downloaded and processed successfully. Saved to cover_images/processed_image_5110.jpg
# Total number of records processed so far: 213
# Image 5119 downloaded and processed successfully. Saved to cover_images/processed_image_5119.jpg
# Total number of records processed so far: 214
# Image 5120 downloaded and processed successfully. Saved to cover_images/processed_image_5120.jpg
# Total number of records processed so far: 215
# Image 5124 downloaded and processed successfully. Saved to cover_images/processed_image_5124.jpg
# Total number of records processed so far: 216
# Image 5128 downloaded and processed successfully. Saved to cover_images/processed_image_5128.jpg
# Total number of records processed so far: 217
# Image 5150 downloaded and processed successfully. Saved to cover_images/processed_image_5150.jpg
# Total number of records processed so far: 218
# Image 5212 downloaded and processed successfully. Saved to cover_images/processed_image_5212.jpg
# Total number of records processed so far: 219
# Image 5267 downloaded and processed successfully. Saved to cover_images/processed_image_5267.jpg
# Total number of records processed so far: 220
# Image 5285 downloaded and processed successfully. Saved to cover_images/processed_image_5285.jpg
# Total number of records processed so far: 221
# Image 5292 downloaded and processed successfully. Saved to cover_images/processed_image_5292.jpg
# Total number of records processed so far: 222
# Image 5347 downloaded and processed successfully. Saved to cover_images/processed_image_5347.jpg
# Total number of records processed so far: 223
# Image 5422 downloaded and processed successfully. Saved to cover_images/processed_image_5422.jpg
# Total number of records processed so far: 224
# Image 5491 downloaded and processed successfully. Saved to cover_images/processed_image_5491.jpg
# Total number of records processed so far: 225
# Image 5529 downloaded and processed successfully. Saved to cover_images/processed_image_5529.jpg
# Total number of records processed so far: 226
# Image 5550 downloaded and processed successfully. Saved to cover_images/processed_image_5550.jpg
# Total number of records processed so far: 227
# Image 5578 downloaded and processed successfully. Saved to cover_images/processed_image_5578.jpg
# Total number of records processed so far: 228
# Image 5582 downloaded and processed successfully. Saved to cover_images/processed_image_5582.jpg
# Total number of records processed so far: 229
# Image 5705 downloaded and processed successfully. Saved to cover_images/processed_image_5705.jpg
# Total number of records processed so far: 230
# Image 5733 downloaded and processed successfully. Saved to cover_images/processed_image_5733.jpg
# Total number of records processed so far: 231
# Image 5734 downloaded and processed successfully. Saved to cover_images/processed_image_5734.jpg
# Total number of records processed so far: 232
# Image 5785 downloaded and processed successfully. Saved to cover_images/processed_image_5785.jpg
# Total number of records processed so far: 233
# Image 5790 downloaded and processed successfully. Saved to cover_images/processed_image_5790.jpg
# Total number of records processed so far: 234
# Image 5797 downloaded and processed successfully. Saved to cover_images/processed_image_5797.jpg
# Total number of records processed so far: 235
# Image 5836 downloaded and processed successfully. Saved to cover_images/processed_image_5836.jpg
# Total number of records processed so far: 236
# Image 5910 downloaded and processed successfully. Saved to cover_images/processed_image_5910.jpg
# Total number of records processed so far: 237
# Image 5925 downloaded and processed successfully. Saved to cover_images/processed_image_5925.jpg
# Total number of records processed so far: 238
# Image 5926 downloaded and processed successfully. Saved to cover_images/processed_image_5926.jpg
# Total number of records processed so far: 239
# Image 5927 downloaded and processed successfully. Saved to cover_images/processed_image_5927.jpg
# Total number of records processed so far: 240
# Image 5929 downloaded and processed successfully. Saved to cover_images/processed_image_5929.jpg
# Total number of records processed so far: 241
# Image 6020 downloaded and processed successfully. Saved to cover_images/processed_image_6020.jpg
# Total number of records processed so far: 242
# Image 6049 downloaded and processed successfully. Saved to cover_images/processed_image_6049.jpg
# Total number of records processed so far: 243
# Image 6058 downloaded and processed successfully. Saved to cover_images/processed_image_6058.jpg
# Total number of records processed so far: 244
# Image 6097 downloaded and processed successfully. Saved to cover_images/processed_image_6097.jpg
# Total number of records processed so far: 245
# Image 6117 downloaded and processed successfully. Saved to cover_images/processed_image_6117.jpg
# Total number of records processed so far: 246
# Image 6118 downloaded and processed successfully. Saved to cover_images/processed_image_6118.jpg
# Total number of records processed so far: 247
# Image 6119 downloaded and processed successfully. Saved to cover_images/processed_image_6119.jpg
# Total number of records processed so far: 248
# Image 6120 downloaded and processed successfully. Saved to cover_images/processed_image_6120.jpg
# Total number of records processed so far: 249
# Image 6121 downloaded and processed successfully. Saved to cover_images/processed_image_6121.jpg
# Total number of records processed so far: 250
# Image 6125 downloaded and processed successfully. Saved to cover_images/processed_image_6125.jpg
# Total number of records processed so far: 251
# Image 6126 downloaded and processed successfully. Saved to cover_images/processed_image_6126.jpg
# Total number of records processed so far: 252
# Image 6137 downloaded and processed successfully. Saved to cover_images/processed_image_6137.jpg
# Total number of records processed so far: 253
# Image 6146 downloaded and processed successfully. Saved to cover_images/processed_image_6146.jpg
# Total number of records processed so far: 254
# Image 6154 downloaded and processed successfully. Saved to cover_images/processed_image_6154.jpg
# Total number of records processed so far: 255
# Image 6194 downloaded and processed successfully. Saved to cover_images/processed_image_6194.jpg
# Total number of records processed so far: 256
# Image 6197 downloaded and processed successfully. Saved to cover_images/processed_image_6197.jpg
# Total number of records processed so far: 257
# Image 6222 downloaded and processed successfully. Saved to cover_images/processed_image_6222.jpg
# Total number of records processed so far: 258
# Image 6316 downloaded and processed successfully. Saved to cover_images/processed_image_6316.jpg
# Total number of records processed so far: 259
# Image 6319 downloaded and processed successfully. Saved to cover_images/processed_image_6319.jpg
# Total number of records processed so far: 260
# Image 6347 downloaded and processed successfully. Saved to cover_images/processed_image_6347.jpg
# Total number of records processed so far: 261
# Image 6350 downloaded and processed successfully. Saved to cover_images/processed_image_6350.jpg
# Total number of records processed so far: 262
# Image 6363 downloaded and processed successfully. Saved to cover_images/processed_image_6363.jpg
# Total number of records processed so far: 263
# Image 6408 downloaded and processed successfully. Saved to cover_images/processed_image_6408.jpg
# Total number of records processed so far: 264
# Image 6415 downloaded and processed successfully. Saved to cover_images/processed_image_6415.jpg
# Total number of records processed so far: 265
# Image 6434 downloaded and processed successfully. Saved to cover_images/processed_image_6434.jpg
# Total number of records processed so far: 266
# Image 6447 downloaded and processed successfully. Saved to cover_images/processed_image_6447.jpg
# Total number of records processed so far: 267
# Image 6499 downloaded and processed successfully. Saved to cover_images/processed_image_6499.jpg
# Total number of records processed so far: 268
# Image 6537 downloaded and processed successfully. Saved to cover_images/processed_image_6537.jpg
# Total number of records processed so far: 269
# Image 6541 downloaded and processed successfully. Saved to cover_images/processed_image_6541.jpg
# Total number of records processed so far: 270
# Image 6547 downloaded and processed successfully. Saved to cover_images/processed_image_6547.jpg
# Total number of records processed so far: 271
# Image 6548 downloaded and processed successfully. Saved to cover_images/processed_image_6548.jpg
# Total number of records processed so far: 272
# Image 6553 downloaded and processed successfully. Saved to cover_images/processed_image_6553.jpg
# Total number of records processed so far: 273
# Image 6554 downloaded and processed successfully. Saved to cover_images/processed_image_6554.jpg
# Total number of records processed so far: 274
# Image 6556 downloaded and processed successfully. Saved to cover_images/processed_image_6556.jpg
# Total number of records processed so far: 275
# Image 6579 downloaded and processed successfully. Saved to cover_images/processed_image_6579.jpg
# Total number of records processed so far: 276
# Image 6610 downloaded and processed successfully. Saved to cover_images/processed_image_6610.jpg
# Total number of records processed so far: 277
# Image 6632 downloaded and processed successfully. Saved to cover_images/processed_image_6632.jpg
# Total number of records processed so far: 278
# Image 6636 downloaded and processed successfully. Saved to cover_images/processed_image_6636.jpg
# Total number of records processed so far: 279
# Image 6639 downloaded and processed successfully. Saved to cover_images/processed_image_6639.jpg
# Total number of records processed so far: 280
# Image 6650 downloaded and processed successfully. Saved to cover_images/processed_image_6650.jpg
# Total number of records processed so far: 281
# Image 6657 downloaded and processed successfully. Saved to cover_images/processed_image_6657.jpg
# Total number of records processed so far: 282
# Image 6659 downloaded and processed successfully. Saved to cover_images/processed_image_6659.jpg
# Total number of records processed so far: 283
# Image 6676 downloaded and processed successfully. Saved to cover_images/processed_image_6676.jpg
# Total number of records processed so far: 284
# Image 6703 downloaded and processed successfully. Saved to cover_images/processed_image_6703.jpg
# Total number of records processed so far: 285
# Image 6706 downloaded and processed successfully. Saved to cover_images/processed_image_6706.jpg
# Total number of records processed so far: 286
# Image 6720 downloaded and processed successfully. Saved to cover_images/processed_image_6720.jpg
# Total number of records processed so far: 287
# Image 6730 downloaded and processed successfully. Saved to cover_images/processed_image_6730.jpg
# Total number of records processed so far: 288
# Image 6731 downloaded and processed successfully. Saved to cover_images/processed_image_6731.jpg
# Total number of records processed so far: 289
# Image 6744 downloaded and processed successfully. Saved to cover_images/processed_image_6744.jpg
# Total number of records processed so far: 290
# Image 6779 downloaded and processed successfully. Saved to cover_images/processed_image_6779.jpg
# Total number of records processed so far: 291
# Image 6829 downloaded and processed successfully. Saved to cover_images/processed_image_6829.jpg
# Total number of records processed so far: 292
# Image 6831 downloaded and processed successfully. Saved to cover_images/processed_image_6831.jpg
# Total number of records processed so far: 293
# Image 6834 downloaded and processed successfully. Saved to cover_images/processed_image_6834.jpg
# Total number of records processed so far: 294
# Image 6835 downloaded and processed successfully. Saved to cover_images/processed_image_6835.jpg
# Total number of records processed so far: 295
# Image 6876 downloaded and processed successfully. Saved to cover_images/processed_image_6876.jpg
# Total number of records processed so far: 296
# Image 6915 downloaded and processed successfully. Saved to cover_images/processed_image_6915.jpg
# Total number of records processed so far: 297
# Image 6953 downloaded and processed successfully. Saved to cover_images/processed_image_6953.jpg
# Total number of records processed so far: 298
# Image 6995 downloaded and processed successfully. Saved to cover_images/processed_image_6995.jpg
# Total number of records processed so far: 299
# Image 7004 downloaded and processed successfully. Saved to cover_images/processed_image_7004.jpg
# Total number of records processed so far: 300
# Image 7013 downloaded and processed successfully. Saved to cover_images/processed_image_7013.jpg
# Total number of records processed so far: 301
# Image 7025 downloaded and processed successfully. Saved to cover_images/processed_image_7025.jpg
# Total number of records processed so far: 302
# Image 7055 downloaded and processed successfully. Saved to cover_images/processed_image_7055.jpg
# Total number of records processed so far: 303
# Image 7061 downloaded and processed successfully. Saved to cover_images/processed_image_7061.jpg
# Total number of records processed so far: 304
# Image 7076 downloaded and processed successfully. Saved to cover_images/processed_image_7076.jpg
# Total number of records processed so far: 305
# Image 7093 downloaded and processed successfully. Saved to cover_images/processed_image_7093.jpg
# Total number of records processed so far: 306
# Image 7105 downloaded and processed successfully. Saved to cover_images/processed_image_7105.jpg
# Total number of records processed so far: 307
# Image 7126 downloaded and processed successfully. Saved to cover_images/processed_image_7126.jpg
# Total number of records processed so far: 308
# Image 7150 downloaded and processed successfully. Saved to cover_images/processed_image_7150.jpg
# Total number of records processed so far: 309
# Image 7218 downloaded and processed successfully. Saved to cover_images/processed_image_7218.jpg
# Total number of records processed so far: 310
# Image 7290 downloaded and processed successfully. Saved to cover_images/processed_image_7290.jpg
# Total number of records processed so far: 311
# Image 7306 downloaded and processed successfully. Saved to cover_images/processed_image_7306.jpg
# Total number of records processed so far: 312
# Image 7307 downloaded and processed successfully. Saved to cover_images/processed_image_7307.jpg
# Total number of records processed so far: 313
# Image 7310 downloaded and processed successfully. Saved to cover_images/processed_image_7310.jpg
# Total number of records processed so far: 314
# Image 7319 downloaded and processed successfully. Saved to cover_images/processed_image_7319.jpg
# Total number of records processed so far: 315
# Image 7320 downloaded and processed successfully. Saved to cover_images/processed_image_7320.jpg
# Total number of records processed so far: 316
# Image 7325 downloaded and processed successfully. Saved to cover_images/processed_image_7325.jpg
# Total number of records processed so far: 317
# Image 7341 downloaded and processed successfully. Saved to cover_images/processed_image_7341.jpg
# Total number of records processed so far: 318
# Image 7347 downloaded and processed successfully. Saved to cover_images/processed_image_7347.jpg
# Total number of records processed so far: 319
# Image 7354 downloaded and processed successfully. Saved to cover_images/processed_image_7354.jpg
# Total number of records processed so far: 320
# Image 7378 downloaded and processed successfully. Saved to cover_images/processed_image_7378.jpg
# Total number of records processed so far: 321
# Image 7379 downloaded and processed successfully. Saved to cover_images/processed_image_7379.jpg
# Total number of records processed so far: 322
# Image 7380 downloaded and processed successfully. Saved to cover_images/processed_image_7380.jpg
# Total number of records processed so far: 323
# Image 7386 downloaded and processed successfully. Saved to cover_images/processed_image_7386.jpg
# Total number of records processed so far: 324
# Image 7457 downloaded and processed successfully. Saved to cover_images/processed_image_7457.jpg
# Total number of records processed so far: 325
# Image 7466 downloaded and processed successfully. Saved to cover_images/processed_image_7466.jpg
# Total number of records processed so far: 326
# Image 7510 downloaded and processed successfully. Saved to cover_images/processed_image_7510.jpg
# Total number of records processed so far: 327
# Image 7547 downloaded and processed successfully. Saved to cover_images/processed_image_7547.jpg
# Total number of records processed so far: 328
# Image 7564 downloaded and processed successfully. Saved to cover_images/processed_image_7564.jpg
# Total number of records processed so far: 329
# Image 7644 downloaded and processed successfully. Saved to cover_images/processed_image_7644.jpg
# Total number of records processed so far: 330
# Image 7663 downloaded and processed successfully. Saved to cover_images/processed_image_7663.jpg
# Total number of records processed so far: 331
# Image 7674 downloaded and processed successfully. Saved to cover_images/processed_image_7674.jpg
# Total number of records processed so far: 332
# Image 7704 downloaded and processed successfully. Saved to cover_images/processed_image_7704.jpg
# Total number of records processed so far: 333
# Image 7721 downloaded and processed successfully. Saved to cover_images/processed_image_7721.jpg
# Total number of records processed so far: 334
# Image 7731 downloaded and processed successfully. Saved to cover_images/processed_image_7731.jpg
# Total number of records processed so far: 335
# Image 7744 downloaded and processed successfully. Saved to cover_images/processed_image_7744.jpg
# Total number of records processed so far: 336
# Image 7787 downloaded and processed successfully. Saved to cover_images/processed_image_7787.jpg
# ...
# Image 97875 downloaded and processed successfully. Saved to cover_images/processed_image_97875.jpg
# Total number of records processed so far: 4615
# Image 97899 downloaded and processed successfully. Saved to cover_images/processed_image_97899.jpg
# Total number of records processed so far: 4616
# Image 97904 downloaded and processed successfully. Saved to cover_images/processed_image_97904.jpg
# Total number of records processed so far: 4617
# Image 97905 downloaded and processed successfully. Saved to cover_images/processed_image_97905.jpg
# Total number of records processed so far: 4618
# Image 97921 downloaded and processed successfully. Saved to cover_images/processed_image_97921.jpg
# Total number of records processed so far: 4619
# Image 97964 downloaded and processed successfully. Saved to cover_images/processed_image_97964.jpg
# Total number of records processed so far: 4620
# Image 97971 downloaded and processed successfully. Saved to cover_images/processed_image_97971.jpg
# Total number of records processed so far: 4621
# Image 97978 downloaded and processed successfully. Saved to cover_images/processed_image_97978.jpg
# Total number of records processed so far: 4622
# Image 97979 downloaded and processed successfully. Saved to cover_images/processed_image_97979.jpg
# Total number of records processed so far: 4623
# Image 98032 downloaded and processed successfully. Saved to cover_images/processed_image_98032.jpg
# Total number of records processed so far: 4624
# Image 98073 downloaded and processed successfully. Saved to cover_images/processed_image_98073.jpg
# Total number of records processed so far: 4625
# Image 98112 downloaded and processed successfully. Saved to cover_images/processed_image_98112.jpg
# Total number of records processed so far: 4626
# Image 98126 downloaded and processed successfully. Saved to cover_images/processed_image_98126.jpg
# Total number of records processed so far: 4627
# Image 98136 downloaded and processed successfully. Saved to cover_images/processed_image_98136.jpg
# Total number of records processed so far: 4628
# Image 98138 downloaded and processed successfully. Saved to cover_images/processed_image_98138.jpg
# Total number of records processed so far: 4629
# Image 98140 downloaded and processed successfully. Saved to cover_images/processed_image_98140.jpg
# Total number of records processed so far: 4630
# Image 98142 downloaded and processed successfully. Saved to cover_images/processed_image_98142.jpg
# Total number of records processed so far: 4631
# Image 98143 downloaded and processed successfully. Saved to cover_images/processed_image_98143.jpg
# Total number of records processed so far: 4632
# Image 98152 downloaded and processed successfully. Saved to cover_images/processed_image_98152.jpg
# Total number of records processed so far: 4633
# Image 98153 downloaded and processed successfully. Saved to cover_images/processed_image_98153.jpg
# Total number of records processed so far: 4634
# Image 98191 downloaded and processed successfully. Saved to cover_images/processed_image_98191.jpg
# Total number of records processed so far: 4635
# Image 98265 downloaded and processed successfully. Saved to cover_images/processed_image_98265.jpg
# Total number of records processed so far: 4636
# Image 98271 downloaded and processed successfully. Saved to cover_images/processed_image_98271.jpg
# Total number of records processed so far: 4637
# Image 98282 downloaded and processed successfully. Saved to cover_images/processed_image_98282.jpg
# Total number of records processed so far: 4638
# Image 98288 downloaded and processed successfully. Saved to cover_images/processed_image_98288.jpg
# Total number of records processed so far: 4639
# Image 98289 downloaded and processed successfully. Saved to cover_images/processed_image_98289.jpg
# Total number of records processed so far: 4640
# Image 98302 downloaded and processed successfully. Saved to cover_images/processed_image_98302.jpg
# Total number of records processed so far: 4641
# Image 98334 downloaded and processed successfully. Saved to cover_images/processed_image_98334.jpg
# Total number of records processed so far: 4642
# Image 98383 downloaded and processed successfully. Saved to cover_images/processed_image_98383.jpg
# Total number of records processed so far: 4643
# Image 98393 downloaded and processed successfully. Saved to cover_images/processed_image_98393.jpg
# Total number of records processed so far: 4644
# Image 98398 downloaded and processed successfully. Saved to cover_images/processed_image_98398.jpg
# Total number of records processed so far: 4645
# Image 98413 downloaded and processed successfully. Saved to cover_images/processed_image_98413.jpg
# Total number of records processed so far: 4646
# Image 98436 downloaded and processed successfully. Saved to cover_images/processed_image_98436.jpg
# Total number of records processed so far: 4647
# Image 98439 downloaded and processed successfully. Saved to cover_images/processed_image_98439.jpg
# Total number of records processed so far: 4648
# Image 98440 downloaded and processed successfully. Saved to cover_images/processed_image_98440.jpg
# Total number of records processed so far: 4649
# Image 98449 downloaded and processed successfully. Saved to cover_images/processed_image_98449.jpg
# Total number of records processed so far: 4650
# Image 98462 downloaded and processed successfully. Saved to cover_images/processed_image_98462.jpg
# Total number of records processed so far: 4651
# Image 98465 downloaded and processed successfully. Saved to cover_images/processed_image_98465.jpg
# Total number of records processed so far: 4652
# Image 98468 downloaded and processed successfully. Saved to cover_images/processed_image_98468.jpg
# Total number of records processed so far: 4653
# Image 98472 downloaded and processed successfully. Saved to cover_images/processed_image_98472.jpg
# Total number of records processed so far: 4654
# Image 98508 downloaded and processed successfully. Saved to cover_images/processed_image_98508.jpg
# Total number of records processed so far: 4655
# Image 98529 downloaded and processed successfully. Saved to cover_images/processed_image_98529.jpg
# Total number of records processed so far: 4656
# Image 98564 downloaded and processed successfully. Saved to cover_images/processed_image_98564.jpg
# Total number of records processed so far: 4657
# Image 98710 downloaded and processed successfully. Saved to cover_images/processed_image_98710.jpg
# Total number of records processed so far: 4658
# Image 98780 downloaded and processed successfully. Saved to cover_images/processed_image_98780.jpg
# Total number of records processed so far: 4659
# Image 98781 downloaded and processed successfully. Saved to cover_images/processed_image_98781.jpg
# Total number of records processed so far: 4660
# Image 98785 downloaded and processed successfully. Saved to cover_images/processed_image_98785.jpg
# Total number of records processed so far: 4661
# Image 98815 downloaded and processed successfully. Saved to cover_images/processed_image_98815.jpg
# Total number of records processed so far: 4662
# Image 98817 downloaded and processed successfully. Saved to cover_images/processed_image_98817.jpg
# Total number of records processed so far: 4663
# Image 98819 downloaded and processed successfully. Saved to cover_images/processed_image_98819.jpg
# Total number of records processed so far: 4664
# Image 98822 downloaded and processed successfully. Saved to cover_images/processed_image_98822.jpg
# Total number of records processed so far: 4665
# Image 98823 downloaded and processed successfully. Saved to cover_images/processed_image_98823.jpg
# Total number of records processed so far: 4666
# Image 98826 downloaded and processed successfully. Saved to cover_images/processed_image_98826.jpg
# Total number of records processed so far: 4667
# Image 98836 downloaded and processed successfully. Saved to cover_images/processed_image_98836.jpg
# Total number of records processed so far: 4668
# Image 98838 downloaded and processed successfully. Saved to cover_images/processed_image_98838.jpg
# Total number of records processed so far: 4669
# Image 98840 downloaded and processed successfully. Saved to cover_images/processed_image_98840.jpg
# Total number of records processed so far: 4670
# Image 98851 downloaded and processed successfully. Saved to cover_images/processed_image_98851.jpg
# Total number of records processed so far: 4671
# Image 98918 downloaded and processed successfully. Saved to cover_images/processed_image_98918.jpg
# Total number of records processed so far: 4672
# Image 98960 downloaded and processed successfully. Saved to cover_images/processed_image_98960.jpg
# Total number of records processed so far: 4673
# Image 98969 downloaded and processed successfully. Saved to cover_images/processed_image_98969.jpg
# Total number of records processed so far: 4674
# Image 99008 downloaded and processed successfully. Saved to cover_images/processed_image_99008.jpg
# Total number of records processed so far: 4675
# Image 99075 downloaded and processed successfully. Saved to cover_images/processed_image_99075.jpg
# Total number of records processed so far: 4676
# Image 99102 downloaded and processed successfully. Saved to cover_images/processed_image_99102.jpg
# Total number of records processed so far: 4677
# Image 99136 downloaded and processed successfully. Saved to cover_images/processed_image_99136.jpg
# Total number of records processed so far: 4678
# Image 99228 downloaded and processed successfully. Saved to cover_images/processed_image_99228.jpg
# Total number of records processed so far: 4679
# Image 99233 downloaded and processed successfully. Saved to cover_images/processed_image_99233.jpg
# Total number of records processed so far: 4680
# Image 99254 downloaded and processed successfully. Saved to cover_images/processed_image_99254.jpg
# Total number of records processed so far: 4681
# Image 99298 downloaded and processed successfully. Saved to cover_images/processed_image_99298.jpg
# Total number of records processed so far: 4682
# Image 99314 downloaded and processed successfully. Saved to cover_images/processed_image_99314.jpg
# Total number of records processed so far: 4683
# Image 99338 downloaded and processed successfully. Saved to cover_images/processed_image_99338.jpg
# Total number of records processed so far: 4684
# Image 99360 downloaded and processed successfully. Saved to cover_images/processed_image_99360.jpg
# Total number of records processed so far: 4685
# Image 99482 downloaded and processed successfully. Saved to cover_images/processed_image_99482.jpg
# Total number of records processed so far: 4686
# Image 99520 downloaded and processed successfully. Saved to cover_images/processed_image_99520.jpg
# Total number of records processed so far: 4687
# Image 99536 downloaded and processed successfully. Saved to cover_images/processed_image_99536.jpg
# Total number of records processed so far: 4688
# Image 99557 downloaded and processed successfully. Saved to cover_images/processed_image_99557.jpg
# Total number of records processed so far: 4689
# Image 99568 downloaded and processed successfully. Saved to cover_images/processed_image_99568.jpg
# Total number of records processed so far: 4690
# Image 99576 downloaded and processed successfully. Saved to cover_images/processed_image_99576.jpg
# Total number of records processed so far: 4691
# Image 99591 downloaded and processed successfully. Saved to cover_images/processed_image_99591.jpg
# Total number of records processed so far: 4692
# Image 99596 downloaded and processed successfully. Saved to cover_images/processed_image_99596.jpg
# Total number of records processed so far: 4693
# Image 99599 downloaded and processed successfully. Saved to cover_images/processed_image_99599.jpg
# Total number of records processed so far: 4694
# Image 99603 downloaded and processed successfully. Saved to cover_images/processed_image_99603.jpg
# Total number of records processed so far: 4695
# Image 99610 downloaded and processed successfully. Saved to cover_images/processed_image_99610.jpg
# Total number of records processed so far: 4696
# Image 99627 downloaded and processed successfully. Saved to cover_images/processed_image_99627.jpg
# Total number of records processed so far: 4697
# Image 99644 downloaded and processed successfully. Saved to cover_images/processed_image_99644.jpg
# Total number of records processed so far: 4698
# Image 99645 downloaded and processed successfully. Saved to cover_images/processed_image_99645.jpg
# Total number of records processed so far: 4699
# Image 99647 downloaded and processed successfully. Saved to cover_images/processed_image_99647.jpg
# Total number of records processed so far: 4700
# Image 99651 downloaded and processed successfully. Saved to cover_images/processed_image_99651.jpg
# Total number of records processed so far: 4701
# Image 99692 downloaded and processed successfully. Saved to cover_images/processed_image_99692.jpg
# Total number of records processed so far: 4702
# Image 99708 downloaded and processed successfully. Saved to cover_images/processed_image_99708.jpg
# Total number of records processed so far: 4703
# Image 99715 downloaded and processed successfully. Saved to cover_images/processed_image_99715.jpg
# Total number of records processed so far: 4704
# Image 99716 downloaded and processed successfully. Saved to cover_images/processed_image_99716.jpg
# Total number of records processed so far: 4705
# Image 99721 downloaded and processed successfully. Saved to cover_images/processed_image_99721.jpg
# Total number of records processed so far: 4706
# Image 99739 downloaded and processed successfully. Saved to cover_images/processed_image_99739.jpg
# Total number of records processed so far: 4707
# Image 99741 downloaded and processed successfully. Saved to cover_images/processed_image_99741.jpg
# Total number of records processed so far: 4708
# Image 99755 downloaded and processed successfully. Saved to cover_images/processed_image_99755.jpg
# Total number of records processed so far: 4709
# Image 99761 downloaded and processed successfully. Saved to cover_images/processed_image_99761.jpg
# Total number of records processed so far: 4710
# Image 99775 downloaded and processed successfully. Saved to cover_images/processed_image_99775.jpg
# Total number of records processed so far: 4711
# Image 99776 downloaded and processed successfully. Saved to cover_images/processed_image_99776.jpg
# Total number of records processed so far: 4712
# Image 99784 downloaded and processed successfully. Saved to cover_images/processed_image_99784.jpg
# Total number of records processed so far: 4713
# Image 99798 downloaded and processed successfully. Saved to cover_images/processed_image_99798.jpg
# Total number of records processed so far: 4714
# Image 99813 downloaded and processed successfully. Saved to cover_images/processed_image_99813.jpg
# Total number of records processed so far: 4715
# Image 99816 downloaded and processed successfully. Saved to cover_images/processed_image_99816.jpg
# Total number of records processed so far: 4716
# Image 99831 downloaded and processed successfully. Saved to cover_images/processed_image_99831.jpg
# Total number of records processed so far: 4717
# Image 99864 downloaded and processed successfully. Saved to cover_images/processed_image_99864.jpg
# Total number of records processed so far: 4718
# Image 99866 downloaded and processed successfully. Saved to cover_images/processed_image_99866.jpg
# Total number of records processed so far: 4719
# Image 99886 downloaded and processed successfully. Saved to cover_images/processed_image_99886.jpg
# Total number of records processed so far: 4720
# Image 99926 downloaded and processed successfully. Saved to cover_images/processed_image_99926.jpg
# Total number of records processed so far: 4721
# Image 99982 downloaded and processed successfully. Saved to cover_images/processed_image_99982.jpg
# Total number of records processed so far: 4722
# Image 99989 downloaded and processed successfully. Saved to cover_images/processed_image_99989.jpg
# Total number of records processed so far: 4723
# Total number of records processed: 4723

# %%
df.to_csv('book_w_images.csv', index = False)
