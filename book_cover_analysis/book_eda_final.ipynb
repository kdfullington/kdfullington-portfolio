# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('book_w_images.csv')

# %%
df.head(2)
# Out:
#                              author bookformat  \
# 0                       Robert Reed  Paperback
# 1  Wu Cheng'en,Arthur Waley,Hu Shih  Paperback
#
#                                                 desc  \
# 0  ship traveled universe longer crew recall true...
# 1  probably popular book history far east classic...
#
#                                                  img       isbn        isbn13  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...  812566572  9.780000e+12
# 1  https://i.gr-assets.com/images/S/compressed.ph...  802130860  9.780000e+12
#
#                                             link  pages  rating  reviews  ...  \
# 0  https://goodreads.com/book/show/100208.Marrow    512    3.82      110  ...
# 1  https://goodreads.com/book/show/100237.Monkey    306    4.02      552  ...
#
#           genre_11  genre_12             genre_13 genre_14 genre_15 genre_16  \
# 0  Science Fiction    Aliens  Speculative Fiction      NaN      NaN      NaN
# ...

# %%
df = df.drop(['genre_0', 'genre_1', 'genre_2', 'genre_3', 'genre_4', 'genre_5', 'genre_6', 'genre_7', 'genre_8', 'genre_9', 'genre_10', 'genre_11', 
              'genre_12', 'genre_13', 'genre_14', 'genre_15', 'genre_16', 'genre_17', 'genre_18', 'genre_19'], axis = 1)

# %%
df.head(2)
# Out:
#                              author bookformat  \
# 0                       Robert Reed  Paperback
# 1  Wu Cheng'en,Arthur Waley,Hu Shih  Paperback
#
#                                                 desc  \
# 0  ship traveled universe longer crew recall true...
# 1  probably popular book history far east classic...
#
#                                                  img       isbn        isbn13  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...  812566572  9.780000e+12
# 1  https://i.gr-assets.com/images/S/compressed.ph...  802130860  9.780000e+12
#
#                                             link  pages  rating  reviews  \
# 0  https://goodreads.com/book/show/100208.Marrow    512    3.82      110
# 1  https://goodreads.com/book/show/100237.Monkey    306    4.02      552
#
#                              title  totalratings  \
# 0                           Marrow          2051
# 1  Monkey: The Journey to the West          6147
#
#                             cover_image
# ...

# %%
# Set the size of the figure
plt.figure(figsize = (12, 6))

# Plotting the histogram using Pandas and Matplotlib
df.pages.plot(kind = 'hist', bins = range(min(df.pages), max(df.pages) + 1), edgecolor = 'blue')

# Adding labels and title
plt.xlabel('Number of Pages')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Pages')

# Display the plot
plt.show()

# %%
df.pages.describe()
# Out:
# count    4723.000000
# mean      296.936058
# std       143.642500
# min         0.000000
# 25%       199.000000
# 50%       305.000000
# 75%       377.000000
# max      1000.000000
# Name: pages, dtype: float64

# %%
df = df[df.pages > 0]

# %%
# Set the size of the figure
plt.figure(figsize = (12, 6))

# Plotting the histogram using Pandas and Matplotlib
df.pages.plot(kind = 'hist', bins = range(min(df.pages), max(df.pages) + 1), edgecolor = 'blue')

# Adding labels and title
plt.xlabel('Number of Pages')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Pages')

# Display the plot
plt.show()

# %%
# Set the size of the figure
plt.figure(figsize = (12, 6))

# Plotting the histogram using Pandas and Matplotlib
df.rating.plot(kind = 'hist', bins = 20, edgecolor = 'blue')

# Adding labels and title
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.title('Histogram of Ratings')

# Display the plot
plt.show()

# %%
# Set the size of the figure
plt.figure(figsize = (12, 6))

# Plotting the histogram using Pandas and Matplotlib
df.reviews.plot(kind = 'hist', bins = 200, edgecolor = 'blue')

# Adding labels and title
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Reviews')

# Display the plot
plt.show()

# %%
# Set the size of the figure
plt.figure(figsize = (12, 6))

# Plotting the histogram using Pandas and Matplotlib
df.totalratings.plot(kind = 'hist', bins = 30, edgecolor = 'blue')

# Adding labels and title
plt.xlabel('Total Number of Ratings')
plt.ylabel('Frequency')
plt.title('Histogram of Total Number of Ratings')

# Display the plot
plt.show()

# %%
df.totalratings.describe()
# Out:
# count    4.669000e+03
# mean     1.756001e+04
# std      9.912169e+04
# min      1.001000e+03
# 25%      1.801000e+03
# 50%      3.463000e+03
# 75%      8.645000e+03
# max      3.099689e+06
# Name: totalratings, dtype: float64

# %% [markdown]
# - count    4,669
# - mean     17,560.01
# - std      99,121.69
# - min      1,001
# - 25%      1,801
# - 50%      3,463
# - 75%      8,645
# - max      3,099,689

# %%
df = df[df.totalratings < 10000]

# %%
# Set the size of the figure
plt.figure(figsize = (12, 6))

# Plotting the histogram using Pandas and Matplotlib
df.totalratings.plot(kind = 'hist', bins = 30, edgecolor = 'blue')

# Adding labels and title
plt.xlabel('Total Number of Ratings')
plt.ylabel('Frequency')
plt.title('Histogram of Total Number of Ratings')

# Display the plot
plt.show()

# %%
df.totalratings.describe()
# Out:
# count    3627.000000
# mean     3356.915633
# std      2246.904169
# min      1001.000000
# 25%      1559.000000
# 50%      2569.000000
# 75%      4518.000000
# max      9989.000000
# Name: totalratings, dtype: float64

# %% [markdown]
# - count    3627.000000
# - mean     3356.915633
# - std      2246.904169
# - min      1001.000000
# - 25%      1559.000000
# - 50%      2569.000000
# - 75%      4518.000000
# - max      9989.000000

# %%
df.head(2)
# Out:
#                              author bookformat  \
# 0                       Robert Reed  Paperback
# 1  Wu Cheng'en,Arthur Waley,Hu Shih  Paperback
#
#                                                 desc  \
# 0  ship traveled universe longer crew recall true...
# 1  probably popular book history far east classic...
#
#                                                  img       isbn        isbn13  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...  812566572  9.780000e+12
# 1  https://i.gr-assets.com/images/S/compressed.ph...  802130860  9.780000e+12
#
#                                             link  pages  rating  reviews  \
# 0  https://goodreads.com/book/show/100208.Marrow    512    3.82      110
# 1  https://goodreads.com/book/show/100237.Monkey    306    4.02      552
#
#                              title  totalratings  \
# 0                           Marrow          2051
# 1  Monkey: The Journey to the West          6147
#
#                             cover_image
# ...
